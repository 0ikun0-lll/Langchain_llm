# %% [markdown]
# ## 大模型调用
#
# 举例:deepseek,zhipu,tongyi

# %%
import os
from typing import override

from dotenv import load_dotenv
from langchain_deepseek import ChatDeepSeek
from langchain_openai import ChatOpenAI

load_dotenv(override= True)

DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

llm_deepseek = ChatDeepSeek(
    #api_key= DEEPSEEK_API_KEY,
    #base_url= DEEPSEEK_BASE_URL,
    model= "deepseek-v4-flash"
)

llm_deepseek.invoke("一句话介绍自己")
# Out:
# AIMessage(content='我是DeepSeek，一个由深度求索公司打造的AI助手，乐于帮你解答问题、提供建议。', additional_kwargs={'refusal': None, 'reasoning_content': '我们只需要简单介绍自己。用户要求“一句话介绍自己”，所以用一句话回答。可以说明是AI助手。'}, response_metadata={'token_usage': {'completion_tokens': 48, 'prompt_tokens': 86, 'total_tokens': 134, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 24, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 86}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_a18b46594c_prod0820_fp8_kvcache_20260402', 'id': '9e8e3739-cbd8-4c42-b654-e1f32f3add05', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019fc05c-9194-7663-a08b-1e8006602a80-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 86, 'output_tokens': 48, 'total_tokens': 134, 'input_token_details': {'cache_read': 0}, 'output_t
# ...

# %%
from langchain_community.chat_models import ChatTongyi
import os
import dotenv

dotenv.load_dotenv(override= True)

DASHSCOPE_API_KEY = os.getenv("DASHSCOPE_API_KEY")
TONGYI_BASE_URL = os.getenv("TONGYI_BASE_URL")

llm_tongyi = ChatTongyi(
    api_key= DASHSCOPE_API_KEY,
    model= "qwen-max"
)

llm_tongyi.invoke("一句话介绍自己")
# Out:
# AIMessage(content='我是Qwen，来自阿里云的超大规模语言模型，致力于帮助用户获得准确、有用的信息。', additional_kwargs={}, response_metadata={'model_name': 'qwen-max', 'finish_reason': 'stop', 'request_id': '0f5f8972-3b1d-9197-a18e-6fe60d1e46f0', 'token_usage': {'input_tokens': 11, 'output_tokens': 22, 'prompt_tokens_details': {'cached_tokens': 0}, 'total_tokens': 33}}, id='lc_run--019fc073-9b10-75e1-ac89-72ea25d2adc9-0', tool_calls=[], invalid_tool_calls=[])

# %% [markdown]
# ## 兼容调用-OpenAI

# %%
import os
import dotenv
from langchain_openai import ChatOpenAI

dotenv.load_dotenv(override= True)
DEEPSEEK_API_KEY=os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL=os.getenv("DEEPSEEK_BASE_URL")

llm_deepseek = ChatOpenAI(
    api_key= DEEPSEEK_API_KEY,
    base_url= DEEPSEEK_BASE_URL,
    model= "deepseek-v4-flash"
)

print(llm_deepseek.invoke("介绍自己"))
# Out:
# content='你好！我是 **DeepSeek**，由深度求索公司开发的 AI 助手，目前是最新版的 V3.2 模型。\n\n简单介绍一下我自己：\n\n- **擅长文字对话**：回答问题、写作、翻译、编程、分析、脑暴等等都可以。\n- **支持文件上传**：可以上传图片、PDF、Word、Excel、PPT 等文件，我会读取其中的文字信息帮你处理。\n- **支持阅读链接**：你发给我网页链接，我可以帮你提取和分析内容。\n- **支持联网搜索**：需要你在客户端手动打开联网开关，我就能获取最新信息。\n- **超长上下文**：我有 1M 的上下文窗口，可以一次性处理很长的内容，比如整本小说。\n- **完全免费**：Web 端和 App 端都可以使用。\n- **知识截止时间**：到 2025 年 5 月。\n\n我虽然不是多模态模型，不能直接“看图理解”，但可以读取图片中的文字信息。\n\n有什么想聊的，或者需要帮忙的，尽管问我～ 😊' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 1972, 'prompt_tokens': 85, 'total_tokens': 2057, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 1748, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 85}, 'model_provider': 'openai', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_a18b46594c_prod0820_fp8_kvcache_20260402', 'id': 'c5279
# ...

# %% [markdown]
# ## init_chat_model

# %%
from langchain.chat_models import init_chat_model
import os
import dotenv

dotenv.load_dotenv(override= True)
DEEPSEEK_API_KEY=os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL=os.getenv("DEEPSEEK_BASE_URL")

llm_deepseek = init_chat_model(
    api_key= DEEPSEEK_API_KEY,
    base_url= DEEPSEEK_BASE_URL,
    model= "deepseek-v4-flash"
)

print(llm_deepseek.invoke("介绍自己"))
# Out:
# content='你好！我是 DeepSeek，由深度求索公司创造的 AI 助手。😊\n\n我可以帮你解答问题、提供建议、处理文字信息、分析文档等。我支持长上下文（1M token），可以一次性处理像《三体》三部曲那样的大体量内容，也能读取你上传的图片、PDF、Word、Excel 等文件中的文字信息。\n\n我完全免费，没有任何收费计划，你可以放心使用。有什么我可以帮你的吗？' additional_kwargs={'refusal': None, 'reasoning_content': '我们 need answer in Chinese. Need introduce self as assistant. Mention capabilities, no specific name? "我是 DeepSeek" maybe. Need be helpful. Keep concise.'} response_metadata={'token_usage': {'completion_tokens': 133, 'prompt_tokens': 85, 'total_tokens': 218, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 34, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 85}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_a18b46594c_prod0820_fp8_kvcache_20260402', 'id': '925bb6d2-39f5-4099-b9b4-7c22fad2d698', 'finish_reason': 'stop', 'log
# ...
